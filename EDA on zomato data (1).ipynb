# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install --upgrade --pre notebook
# Out:
# Requirement already satisfied: notebook in c:\users\chint\anaconda3\lib\site-packages (7.0.0a5)
# Requirement already satisfied: notebook-shim<0.2,>=0.1 in c:\users\chint\anaconda3\lib\site-packages (from notebook) (0.1.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.13 in c:\users\chint\anaconda3\lib\site-packages (from notebook) (2.15.1)
# Requirement already satisfied: tornado>=6.1.0 in c:\users\chint\anaconda3\lib\site-packages (from notebook) (6.1)
# Requirement already satisfied: jupyter-server<2,>=1.16.0 in c:\users\chint\anaconda3\lib\site-packages (from notebook) (1.18.1)
# Requirement already satisfied: jupyterlab<5,>=4.0.0a24 in c:\users\chint\anaconda3\lib\site-packages (from notebook) (4.0.0a27)
# Requirement already satisfied: websocket-client in c:\users\chint\anaconda3\lib\site-packages (from jupyter-server<2,>=1.16.0->notebook) (0.58.0)
# Requirement already satisfied: nbformat>=5.2.0 in c:\users\chint\anaconda3\lib\site-packages (from jupyter-server<2,>=1.16.0->notebook) (5.3.0)
# Requirement already satisfied: packaging in c:\users\chint\anaconda3\lib\site-packages (from jupyter-server<2,>=1.16.0->notebook) (21.3)
# Requirement already satisfied: argon2-cffi in c:\users\chint\anaconda3\lib\site-packages (from jupyter-server<2,>=1.16.0->notebook) (21.3.0)
# Requirement already satisfied: prometheus-client in c:\users\chint\anaconda3\lib\site-packages (from jupyter-server<2,>=1.16.0->notebook) (0.13.1)
# Requirement already satisfied: traitlets>=5.1 in c:\users\chint\anaconda3\lib\site-packages (from jupyter-server<2,>=1.16.0->notebook) (5.1.1)
# Requirement already satisfied: Send2Trash in c:\users\chint\anaconda3\lib\site-packages (from jupyter-server<2,>=1.16.0->notebook) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\chint\anaconda3\lib\site-packages (from jupyter-server<2,>=1.16.0->notebook) (6.1.12)
# Requirement already satisfied: pyzmq>=17 in c:\users\chint\anaconda3\lib\site-packages (from jupyter-server<2,>=1.16.0->notebook) (22.3.0)
# Requirement already satisfied: pywinpty in c:\users\chint\anaconda3\lib\site-packages (from jupyter-server<2,>=1.16.0->notebook) (2.0.2)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\chint\anaconda3\lib\site-packages (from jupyter-server<2,>=1.16.0->notebook) (6.4.4)
# Requirement already satisfied: jinja2 in c:\users\chint\anaconda3\lib\site-packages (from jupyter-server<2,>=1.16.0->notebook) (3.1.2)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\chint\anaconda3\lib\site-packages (from jupyter-server<2,>=1.16.0->notebook) (3.5.0)
# Requirement already satisfied: jupyter-core>=4.7.0 in c:\users\chint\anaconda3\lib\site-packages (from jupyter-server<2,>=1.16.0->notebook) (4.9.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\chint\anaconda3\lib\site-packages (from jupyter-server<2,>=1.16.0->notebook) (0.13.1)
# Requirement already satisfied: idna>=2.8 in c:\users\chint\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server<2,>=1.16.0->notebook) (3.3)
# Requirement already satisfied: sniffio>=1.1 in c:\users\chint\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server<2,>=1.16.0->notebook) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\chint\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->jupyter-server<2,>=1.16.0->notebook) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\chint\anaconda3\lib\site-packages (from jupyter-core>=4.7.0->jupyter-server<2,>=1.16.0->notebook) (302)
# Requirement already satisfied: tomli in c:\users\chint\anaconda3\lib\site-packages (from jupyterlab<5,>=4.0.0a24->notebook) (1.2.2)
# Requirement already satisfied: jupyter-server-ydoc<0.2.0,>=0.1.9 in c:\users\chint\anaconda3\lib\site-packages (from jupyterlab<5,>=4.0.0a24->notebook) (0.1.11)
# Requirement already satisfied: ipykernel in c:\users\chint\anaconda3\lib\site-packages (from jupyterlab<5,>=4.0.0a24->notebook) (6.9.1)
# Requirement already satisfied: importlib-metadata>=3.6 in c:\users\chint\anaconda3\lib\site-packages (from jupyterlab<5,>=4.0.0a24->notebook) (4.11.3)
# Requirement already satisfied: jupyter-lsp>=1.5.1 in c:\users\chint\anaconda3\lib\site-packages (from jupyterlab<5,>=4.0.0a24->notebook) (1.5.1)
# Requirement already satisfied: ypy-websocket in c:\users\chint\anaconda3\lib\site-packages (from jupyterlab<5,>=4.0.0a24->notebook) (0.3.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\chint\anaconda3\lib\site-packages (from importlib-metadata>=3.6->jupyterlab<5,>=4.0.0a24->notebook) (3.7.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\chint\anaconda3\lib\site-packages (from jinja2->jupyter-server<2,>=1.16.0->notebook) (2.0.1)
# Requirement already satisfied: entrypoints in c:\users\chint\anaconda3\lib\site-packages (from jupyter-lsp>=1.5.1->jupyterlab<5,>=4.0.0a24->notebook) (0.4)
# Requirement already satisfied: jupyter-ydoc<0.2.0,>=0.1.16 in c:\users\chint\anaconda3\lib\site-packages (from jupyter-server-ydoc<0.2.0,>=0.1.9->jupyterlab<5,>=4.0.0a24->notebook) (0.1.17)
# Requirement already satisfied: y-py<0.6.0,>=0.5.3 in c:\users\chint\anaconda3\lib\site-packages (from jupyter-ydoc<0.2.0,>=0.1.16->jupyter-server-ydoc<0.2.0,>=0.1.9->jupyterlab<5,>=4.0.0a24->notebook) (0.5.4)
# Requirement already satisfied: setuptools in c:\users\chint\anaconda3\lib\site-packages (from jupyter-ydoc<0.2.0,>=0.1.16->jupyter-server-ydoc<0.2.0,>=0.1.9->jupyterlab<5,>=4.0.0a24->notebook) (61.2.0)
# Requirement already satisfied: requests in c:\users\chint\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.13->notebook) (2.27.1)
# Requirement already satisfied: jsonschema>=3.0.1 in c:\users\chint\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.13->notebook) (4.4.0)
# Requirement already satisfied: babel in c:\users\chint\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.13->notebook) (2.9.1)
# Requirement already satisfied: json5 in c:\users\chint\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.13->notebook) (0.9.6)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\chint\anaconda3\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server<3,>=2.13->notebook) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\chint\anaconda3\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server<3,>=2.13->notebook) (0.18.0)
# Requirement already satisfied: bleach in c:\users\chint\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<2,>=1.16.0->notebook) (4.1.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\chint\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<2,>=1.16.0->notebook) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\chint\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<2,>=1.16.0->notebook) (1.5.0)
# Requirement already satisfied: testpath in c:\users\chint\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<2,>=1.16.0->notebook) (0.5.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\chint\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<2,>=1.16.0->notebook) (4.11.1)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\chint\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<2,>=1.16.0->notebook) (2.11.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\chint\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<2,>=1.16.0->notebook) (0.8.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\chint\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<2,>=1.16.0->notebook) (0.5.13)
# Requirement already satisfied: defusedxml in c:\users\chint\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<2,>=1.16.0->notebook) (0.7.1)
# Requirement already satisfied: nest-asyncio in c:\users\chint\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert>=6.4.4->jupyter-server<2,>=1.16.0->notebook) (1.5.5)
# Requirement already satisfied: fastjsonschema in c:\users\chint\anaconda3\lib\site-packages (from nbformat>=5.2.0->jupyter-server<2,>=1.16.0->notebook) (2.15.1)
# Requirement already satisfied: six>=1.5 in c:\users\chint\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client>=6.1.12->jupyter-server<2,>=1.16.0->notebook) (1.16.0)
# Requirement already satisfied: aiosqlite<1,>=0.17.0 in c:\users\chint\anaconda3\lib\site-packages (from ypy-websocket->jupyterlab<5,>=4.0.0a24->notebook) (0.17.0)
# Requirement already satisfied: aiofiles<1,>=0.8.0 in c:\users\chint\anaconda3\lib\site-packages (from ypy-websocket->jupyterlab<5,>=4.0.0a24->notebook) (0.8.0)
# Requirement already satisfied: typing_extensions>=3.7.2 in c:\users\chint\anaconda3\lib\site-packages (from aiosqlite<1,>=0.17.0->ypy-websocket->jupyterlab<5,>=4.0.0a24->notebook) (4.1.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\chint\anaconda3\lib\site-packages (from argon2-cffi->jupyter-server<2,>=1.16.0->notebook) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\chint\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<2,>=1.16.0->notebook) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\chint\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<2,>=1.16.0->notebook) (2.21)
# Requirement already satisfied: pytz>=2015.7 in c:\users\chint\anaconda3\lib\site-packages (from babel->jupyterlab-server<3,>=2.13->notebook) (2021.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\chint\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<2,>=1.16.0->notebook) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\chint\anaconda3\lib\site-packages (from bleach->nbconvert>=6.4.4->jupyter-server<2,>=1.16.0->notebook) (0.5.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\chint\anaconda3\lib\site-packages (from ipykernel->jupyterlab<5,>=4.0.0a24->notebook) (0.1.2)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\chint\anaconda3\lib\site-packages (from ipykernel->jupyterlab<5,>=4.0.0a24->notebook) (8.2.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\chint\anaconda3\lib\site-packages (from ipykernel->jupyterlab<5,>=4.0.0a24->notebook) (1.5.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\chint\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.0a24->notebook) (0.18.1)
# Requirement already satisfied: backcall in c:\users\chint\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.0a24->notebook) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\chint\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.0a24->notebook) (0.7.5)
# Requirement already satisfied: stack-data in c:\users\chint\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.0a24->notebook) (0.2.0)
# Requirement already satisfied: colorama in c:\users\chint\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.0a24->notebook) (0.4.4)
# Requirement already satisfied: decorator in c:\users\chint\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.0a24->notebook) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\chint\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.0a24->notebook) (3.0.20)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\chint\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.0a24->notebook) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\chint\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.0a24->notebook) (0.2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\chint\anaconda3\lib\site-packages (from packaging->jupyter-server<2,>=1.16.0->notebook) (3.0.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\chint\anaconda3\lib\site-packages (from requests->jupyterlab-server<3,>=2.13->notebook) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chint\anaconda3\lib\site-packages (from requests->jupyterlab-server<3,>=2.13->notebook) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\chint\anaconda3\lib\site-packages (from requests->jupyterlab-server<3,>=2.13->notebook) (1.26.9)
# Requirement already satisfied: pure-eval in c:\users\chint\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.0a24->notebook) (0.2.2)
# Requirement already satisfied: executing in c:\users\chint\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.0a24->notebook) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\chint\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.0a24->notebook) (2.0.5)

# %%
df=pd.read_csv("zomato.csv",encoding="latin-1")

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
# 3  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475  14.585318
# 4  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508  14.584450
#
#                            Cuisines  ...          Currency Has Table booking  \
# 0        French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                          Japanese  ...  Botswana Pula(P)               Yes
# 2  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)               Yes
# 3                   Japanese, Sushi  ...  Botswana Pula(P)                No
# 4                  Japanese, Korean  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
# 2                  No                No                   No           4
# 3                  No                No                   No           4
# 4                  No                No                   No           4
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
# 1               4.5    Dark Green   Excellent   591
# 2               4.4         Green   Very Good   270
# 3               4.9    Dark Green   Excellent   365
# 4               4.8    Dark Green   Excellent   229
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
#                                                 Address  \
# 0     Third Floor, Century City Mall, Kalayaan Avenu...
# 1     Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2     Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3     Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4     Third Floor, Mega Atrium, SM Megamall, Ortigas...
# ...                                                 ...
# 9546  Kemankeô Karamustafa Paôa Mahallesi, RÛ±htÛ±...
# 9547  Koôuyolu Mahallesi, Muhittin íìstí_ndaÛô Cadd...
# 9548  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...
# 9549  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...
# 9550  CafeaÛôa Mahallesi, BademaltÛ± Sokak, No 21/B,...
#
#                                         Locality  \
# 0      Century City Mall, Poblacion, Makati City
# 1     Little Tokyo, Legaspi Village, Makati City
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City
# 3         SM Megamall, Ortigas, Mandaluyong City
# 4         SM Megamall, Ortigas, Mandaluyong City
# ...                                          ...
# 9546                                    Karakí_y
# 9547                                   Koôuyolu
# 9548                                 Kuruí_eôme
# 9549                                 Kuruí_eôme
# 9550                                        Moda
#
#                                        Locality Verbose   Longitude  \
# 0     Century City Mall, Poblacion, Makati City, Mak...  121.027535
# 1     Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831
# 3     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475
# 4     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508
# ...                                                 ...         ...
# 9546                                Karakí_y, ÛÁstanbul   28.977392
# 9547                               Koôuyolu, ÛÁstanbul   29.041297
# 9548                             Kuruí_eôme, ÛÁstanbul   29.034640
# 9549                             Kuruí_eôme, ÛÁstanbul   29.036019
# 9550                                    Moda, ÛÁstanbul   29.026016
#
#        Latitude                          Cuisines  ...          Currency  \
# 0     14.565443        French, Japanese, Desserts  ...  Botswana Pula(P)
# 1     14.553708                          Japanese  ...  Botswana Pula(P)
# 2     14.581404  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)
# 3     14.585318                   Japanese, Sushi  ...  Botswana Pula(P)
# 4     14.584450                  Japanese, Korean  ...  Botswana Pula(P)
# ...         ...                               ...  ...               ...
# 9546  41.022793                           Turkish  ...  Turkish Lira(TL)
# 9547  41.009847   World Cuisine, Patisserie, Cafe  ...  Turkish Lira(TL)
# 9548  41.055817            Italian, World Cuisine  ...  Turkish Lira(TL)
# 9549  41.057979                   Restaurant Cafe  ...  Turkish Lira(TL)
# 9550  40.984776                              Cafe  ...  Turkish Lira(TL)
#
#      Has Table booking Has Online delivery Is delivering now  \
# 0                  Yes                  No                No
# 1                  Yes                  No                No
# 2                  Yes                  No                No
# 3                   No                  No                No
# 4                  Yes                  No                No
# ...                ...                 ...               ...
# 9546                No                  No                No
# 9547                No                  No                No
# 9548                No                  No                No
# 9549                No                  No                No
# 9550                No                  No                No
#
#      Switch to order menu Price range  Aggregate rating  Rating color  \
# 0                      No           3               4.8    Dark Green
# 1                      No           3               4.5    Dark Green
# 2                      No           4               4.4         Green
# 3                      No           4               4.9    Dark Green
# 4                      No           4               4.8    Dark Green
# ...                   ...         ...               ...           ...
# 9546                   No           3               4.1         Green
# 9547                   No           3               4.2         Green
# 9548                   No           4               3.7        Yellow
# 9549                   No           4               4.0         Green
# 9550                   No           2               4.0         Green
#
#      Rating text Votes
# 0      Excellent   314
# 1      Excellent   591
# 2      Very Good   270
# 3      Excellent   365
# 4      Excellent   229
# ...          ...   ...
# 9546   Very Good   788
# 9547   Very Good  1034
# 9548        Good   661
# 9549   Very Good   901
# 9550   Very Good   591
#
# [9551 rows x 21 columns]>

# %%
df.shape
# Out:
# (9551, 21)

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
[feature for feature in df.columns if df[feature].isnull().sum()>0]
# Out:
# ['Cuisines']

# %%
sns.heatmap(df.isnull(),yticklabels=False)
# Out:
# <AxesSubplot:>

# %%
df_county=pd.read_excel("Country-Code.xlsx")
df_county.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
final_df=pd.merge(df,df_county,on='Country Code',how='left')

# %%
final_df.head(3)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
#
#                            Cuisines  ...  Has Table booking  \
# 0        French, Japanese, Desserts  ...                Yes
# 1                          Japanese  ...                Yes
# 2  Seafood, Asian, Filipino, Indian  ...                Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
# 2                  No                No                   No           4
#
#   Aggregate rating  Rating color  Rating text Votes      Country
# 0              4.8    Dark Green    Excellent   314  Phillipines
# 1              4.5    Dark Green    Excellent   591  Phillipines
# 2              4.4         Green    Very Good   270  Phillipines
#
# [3 rows x 22 columns]

# %%
final_df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
country_names=final_df.Country.value_counts().index

# %%
country_val=final_df.Country.value_counts().values

# %%
plt.pie(country_val[:3],labels=country_names[:3])
# Out:
# ([<matplotlib.patches.Wedge at 0x1fc2624dbb0>,
#   <matplotlib.patches.Wedge at 0x1fc26257100>,
#   <matplotlib.patches.Wedge at 0x1fc26257610>],
#  [Text(-1.0829742700952103, 0.19278674827836725, 'India'),
#   Text(1.077281715838356, -0.22240527134123297, 'United States'),
#   Text(1.0995865153823035, -0.03015783794312073, 'United Kingdom')])

# %%
ratings=final_df.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index().rename(columns={0:"Rating Count"})

# %%
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# 15               3.2       Orange     Average           522
# 16               3.3       Orange     Average           483
# 17               3.4       Orange     Average           498
# 18               3.5       Yellow        Good           480
# 19               3.6       Yellow        Good           458
# 20               3.7       Yellow        Good           427
# 21               3.8       Yellow        Good           400
# 22               3.9       Yellow        Good           335
# 23               4.0        Green   Very Good           266
# 24               4.1        Green   Very Good           274
# 25               4.2        Green   Very Good           221
# 26               4.3        Green   Very Good           174
# 27               4.4        Green   Very Good           144
# 28               4.5   Dark Green   Excellent            95
# 29               4.6   Dark Green   Excellent            78
# 30               4.7   Dark Green   Excellent            42
# 31               4.8   Dark Green   Excellent            25
# 32               4.9   Dark Green   Excellent            61

# %%
import matplotlib
matplotlib.rcParams['figure.figsize']=30,20
sns.barplot(x='Aggregate rating',y='Rating Count',data=ratings)
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Rating Count'>

# %%
sns.barplot(x='Aggregate rating',y='Rating Count',hue='Rating color',data=ratings,palette=['white','red','orange','yellow','green'])
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Rating Count'>

# %%
sns.countplot(x='Rating color',data=ratings,palette=['White','red','orange','yellow','green'])
# Out:
# <AxesSubplot:xlabel='Rating color', ylabel='count'>

# %%
final_df[final_df["Rating color"]=='White'].groupby('Country').size().reset_index()
# Out:
#           Country     0
# 0          Brazil     5
# 1           India  2139
# 2  United Kingdom     1
# 3   United States     3

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final_df.groupby(['Currency','Country']).size().reset_index()
# Out:
#                   Currency         Country     0
# 0         Botswana Pula(P)     Phillipines    22
# 1       Brazilian Real(R$)          Brazil    60
# 2                Dollar($)       Australia    24
# 3                Dollar($)          Canada     4
# 4                Dollar($)       Singapore    20
# 5                Dollar($)   United States   434
# 6       Emirati Diram(AED)             UAE    60
# 7       Indian Rupees(Rs.)           India  8652
# 8   Indonesian Rupiah(IDR)       Indonesia    21
# 9            NewZealand($)     New Zealand    40
# 10              Pounds(£)  United Kingdom    80
# 11         Qatari Rial(QR)           Qatar    20
# 12                 Rand(R)    South Africa    60
# 13   Sri Lankan Rupee(LKR)       Sri Lanka    20
# 14        Turkish Lira(TL)          Turkey    34

# %%
final_df.groupby(['Country','Has Online delivery']).size().reset_index()
# Out:
#            Country Has Online delivery     0
# 0        Australia                  No    24
# 1           Brazil                  No    60
# 2           Canada                  No     4
# 3            India                  No  6229
# 4            India                 Yes  2423
# 5        Indonesia                  No    21
# 6      New Zealand                  No    40
# 7      Phillipines                  No    22
# 8            Qatar                  No    20
# 9        Singapore                  No    20
# 10    South Africa                  No    60
# 11       Sri Lanka                  No    20
# 12          Turkey                  No    34
# 13             UAE                  No    32
# 14             UAE                 Yes    28
# 15  United Kingdom                  No    80
# 16   United States                  No   434

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
city_name=final_df.City.value_counts().index

# %%
cities_val=final_df.City.value_counts().values

# %%
plt.pie(cities_val[:5],labels=city_name[:5])
# Out:
# ([<matplotlib.patches.Wedge at 0x1fc3653dd90>,
#   <matplotlib.patches.Wedge at 0x1fc3654b250>,
#   <matplotlib.patches.Wedge at 0x1fc3654b730>,
#   <matplotlib.patches.Wedge at 0x1fc3654bc10>,
#   <matplotlib.patches.Wedge at 0x1fc36557160>],
#  [Text(-0.6145352824185932, 0.9123301960708633, 'New Delhi'),
#   Text(0.0623675251198054, -1.0982305276263407, 'Gurgaon'),
#   Text(0.8789045225625368, -0.6614581167535246, 'Noida'),
#   Text(1.0922218418223437, -0.13058119407559224, 'Faridabad'),
#   Text(1.099946280005612, -0.010871113182029924, 'Ghaziabad')])

# %%
df.Cuisines
# Out:
# 0             French, Japanese, Desserts
# 1                               Japanese
# 2       Seafood, Asian, Filipino, Indian
# 3                        Japanese, Sushi
# 4                       Japanese, Korean
#                       ...
# 9546                             Turkish
# 9547     World Cuisine, Patisserie, Cafe
# 9548              Italian, World Cuisine
# 9549                     Restaurant Cafe
# 9550                                Cafe
# Name: Cuisines, Length: 9551, dtype: object
